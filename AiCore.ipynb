# %%
print("Hello Databricks :)")

# %% [markdown]
# # Heading 1
# **Bold Text**
# *Italic Text*
# [Link](https://www.databricks.com)
# ![Image](https://www.bmimages.com/preview.asp?image=00014493001)

# %%
# %sql
SELECT * FROM wine.wine_red
