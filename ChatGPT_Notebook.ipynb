# %%
# %fs ls /

# %% [markdown]
# The following fails because do not have Unity Catalog Volumes enabled! ...

# %%
# %fs ls Volumes

# %%
# %fs ls Workspace

# %%
# %fs ls databricks-datasets/

# %%
dbutils.fs.ls("/Workspace")

# %%
dbutils.fs.ls("/databricks-datasets/")

# %%
files = dbutils.fs.ls("/databricks-datasets/")
for file in files:
  print(file.name, file.size)

# %%
dbutils.fs.ls("/databricks-datasets/wine-quality")

# %%
df = spark.read.csv("/databricks-datasets/wine-quality/winequality-red.csv", header=True, inferSchema=True)
display(df)

# %%
df.show()

# %%
# %sql
CREATE DATABASE IF NOT EXISTS wine;

# %%
# %sql
SHOW SCHEMAS IN Workspace

# %%
# %sql
SHOW TABLES IN wine

# %%
# %sql
SHOW DATABASES

# %%
# %sql
SELECT current_catalog(), current_schema();

# %%
# %sql
SHOW SCHEMAS

# %%
# %sql
SHOW SCHEMAS in workspace;

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
SELECT current_catalog(), current_schema();

# %%
# %sql
SHOW DATABASES;

# %%
# %sql
USE CATALOG workspace;
USE SCHEMA wine;

# %%
# %sql
SELECT current_catalog(), current_schema();

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.wine.data;

# %%
dbutils.fs.cp(
    "dbfs:/databricks-datasets/wine-quality/winequality-red.csv",
    "dbfs:/Volumes/workspace/wine/data/winequality-red.csv"
)

# %%
# %sql
CREATE TABLE workspace.wine.wine_red AS
SELECT *
FROM csv.`/databricks-datasets/wine-quality/winequality-red.csv`;

# %%
# %sql
SELECT * FROM workspace.wine.wine_red LIMIT 10;

# %%
# %sql
SHOW TABLES IN workspace.wine;

# %%
spark.sql("SHOW TABLES IN workspace.wine")

# %%
# %sql
DESCRIBE DETAIL workspace.wine.wine_red;
